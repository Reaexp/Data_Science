# %%
import pandas as pd
import numpy as np

# %%
heroes_of_the_Dota2_game = pd.read_csv('dota_hero_stats.csv')

# %%
heroes_of_the_Dota2_game.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
heroes_of_the_Dota2_game.groupby('legs')

# %%
heroes_of_the_Dota2_game.sort_values('legs')
# Out:
#      Unnamed: 0 attack_type   id  legs localized_name  \
# 31           31      Ranged   33     0         Enigma
# 14           14      Ranged   15     0          Razor
# 45           45      Ranged   47     0          Viper
# 38           38      Ranged   40     0     Venomancer
# 10           10      Ranged   11     0   Shadow Fiend
# ..          ...         ...  ...   ...            ...
# 56           56      Ranged   58     4    Enchantress
# 15           15       Melee   16     6      Sand King
# 86           86       Melee   88     6   Nyx Assassin
# 103         103      Ranged  105     6        Techies
# 59           59       Melee   61     8    Broodmother
#
#                            name primary_attr  \
# 31         npc_dota_hero_enigma          int
# 14          npc_dota_hero_razor          agi
# 45          npc_dota_hero_viper          agi
# 38     npc_dota_hero_venomancer          agi
# 10      npc_dota_hero_nevermore          agi
# ...

# %%
heroes_of_the_Dota2_game.groupby('legs').count()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
accountancy = pd.read_csv('accountancy.csv')

# %%
accountancy.head(10)
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184
# 5           5    Loopa    F     232
# 6           6    Loopa    B     249
# 7           7     Pupa    F     195
# 8           8     Pupa    A     115
# 9           9     Pupa    E      65

# %%
accountancy.groupby(['Type']).mean()
# Out:
#       Unnamed: 0      Salary
# Type
# A      20.285714  146.142857
# B      26.428571  135.428571
# C      29.500000  134.375000
# D      25.363636  140.909091
# E      21.818182  149.090909
# F      23.833333  170.166667

# %%
accountancy.groupby('Type', as_index=False).aggregate({'Salary': 'mean'})
# Out:
#   Type      Salary
# 0    A  146.142857
# 1    B  135.428571
# 2    C  134.375000
# 3    D  140.909091
# 4    E  149.090909
# 5    F  170.166667

# %%
accountancy.groupby(['Type', 'Executor'], as_index=False).aggregate({'Salary': 'mean'})
# Out:
#    Type Executor      Salary
# 0     A    Loopa   58.000000
# 1     A     Pupa  160.833333
# 2     B    Loopa  145.166667
# 3     B     Pupa   77.000000
# 4     C    Loopa  154.333333
# 5     C     Pupa   74.500000
# 6     D    Loopa  137.714286
# 7     D     Pupa  146.500000
# 8     E    Loopa  164.000000
# 9     E     Pupa  131.200000
# 10    F    Loopa  238.000000
# 11    F     Pupa  136.250000

# %%
heroes_of_the_Dota2_game.head(100)
# Out:
#     Unnamed: 0 attack_type   id  legs  localized_name  \
# 0            0       Melee    1     2       Anti-Mage
# 1            1       Melee    2     2             Axe
# 2            2      Ranged    3     4            Bane
# 3            3       Melee    4     2     Bloodseeker
# 4            4      Ranged    5     2  Crystal Maiden
# ..         ...         ...  ...   ...             ...
# 95          95       Melee   97     4          Magnus
# 96          96       Melee   98     2       Timbersaw
# 97          97       Melee   99     2     Bristleback
# 98          98       Melee  100     2            Tusk
# 99          99      Ranged  101     2   Skywrath Mage
#
#                             name primary_attr  \
# 0         npc_dota_hero_antimage          agi
# 1              npc_dota_hero_axe          str
# 2             npc_dota_hero_bane          int
# 3      npc_dota_hero_bloodseeker          agi
# 4   npc_dota_hero_crystal_maiden          int
# ...

# %%
heroes_of_the_Dota2_game.groupby(['attack_type', 'primary_attr']).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
concentrations = pd.read_csv('algae.csv')

# %%
concentrations.head(1000)
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
concentrations.genus
# Out:
# 0          Fucus
# 1     Saccharina
# 2          Fucus
# 3          Fucus
# 4     Cladophora
# 5     Cladophora
# 6     Cladophora
# 7       Palmaria
# 8     Saccharina
# 9    Ascophyllum
# Name: genus, dtype: object

# %%
concentrations.genus == 'Fucus'
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: genus, dtype: bool

# %%
concentrations.loc[concentrations.genus == 'Fucus', ['genus', 'alanin']]
# Out:
#    genus    alanin
# 0  Fucus  3.711498
# 2  Fucus  0.346431
# 3  Fucus  6.641303

# %%
concentrations.loc[concentrations.genus == 'Fucus'].groupby('genus', as_index=False).alanin.describe().loc[['min', 'mean', 'max']].agg(lambda x: round(x, 2))
# Out:
# Fucus
# min    0    0.35
# mean   0    3.57
# max    0    6.64
# dtype: float64

# %%
concentrations.head(100)
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
concentrations.groupby
# Out:
# 5.468942191008526

# %%
concentrations.groupby('group')\
                        [['sucrose', 'citrate']]\
                        .describe()\
                        .round(2)
# Out:
#       sucrose                                           citrate              \
#         count  mean   std   min   25%   50%   75%   max   count  mean   std
# group
# brown     6.0  4.71  2.34  1.64  3.07  5.00  6.77  6.83     6.0  4.10  2.34
# green     3.0  4.01  1.63  2.45  3.16  3.86  4.79  5.71     3.0  5.29  1.99
# red       1.0  0.70   NaN  0.70  0.70  0.70  0.70  0.70     1.0  5.57   NaN
#
#
#         min   25%   50%   75%   max
# group
# brown  1.07  2.16  5.13  5.53  6.42
# green  3.08  4.46  5.84  6.39  6.94
# red    5.57  5.57  5.57  5.57  5.57

# %%
(concentrations.groupby('group')
               .agg({'citrate': 'var', 'sucrose': lambda x: x.max() - x.min(), 'glucose': 'count'})
               .rename({'glucose': 'genus_count'}, axis=1)
)
# Out:
#         citrate   sucrose  genus_count
# group
# brown  5.468942  5.189345            6
# green  3.950113  3.259662            3
# red         NaN  0.000000            1

# %%
concentrations.groupby('group').agg('describe').T
# Out:
# group                brown     green       red
# sucrose    count  6.000000  3.000000  1.000000
#            mean   4.709666  4.008792  0.704580
#            std    2.336471  1.634817       NaN
#            min    1.636122  2.452623  0.704580
#            25%    3.070321  3.157047  0.704580
#            50%    5.003970  3.861470  0.704580
#            75%    6.773014  4.786877  0.704580
#            max    6.825467  5.712284  0.704580
# alanin     count  6.000000  3.000000  1.000000
#            mean   3.103846  3.997055  3.176440
#            std    2.687071  2.657050       NaN
#            min    0.346431  1.648450  3.176440
#            25%    0.970384  2.555071  3.176440
#            50%    2.483374  3.461692  3.176440
#            75%    5.272747  5.171358  3.176440
#            max    6.641303  6.881024  3.176440
# citrate    count  6.000000  3.000000  1.000000
#            mean   4.098597  5.288311  5.573905
#            std    2.338577  1.987489       NaN
# ...
