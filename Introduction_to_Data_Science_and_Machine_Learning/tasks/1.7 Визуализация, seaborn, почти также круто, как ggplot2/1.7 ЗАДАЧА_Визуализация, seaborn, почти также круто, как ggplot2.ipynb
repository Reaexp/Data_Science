# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

income = pd.read_csv('income.csv')

income.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %% [markdown]
# ### пособы отрисовать простой график зависимости зарплаты от даты

# %%
sns.lineplot(x=income.index, y=income.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
plt.plot(income.index, income.income)

# %%
income['income'].plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=income)
# Out:
# <AxesSubplot:>

# %%
income.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
income.plot()
# Out:
# <AxesSubplot:>

# %%
income.income.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Вам дан датасэт с 2-мя фичами (колонками). Постройте график распределения точек (наблюдений) в пространстве этих 2-ух переменных (одна из них будет x, а другая - y) и напишите число кластеров, формируемых наблюдениями.

# %%
dataset = pd.read_csv('dataset_209770_6.txt', sep=" ")

dataset.head()
# Out:
#              x           y
# 0  1314.440348  503.162333
# 1   395.366323  595.151689
# 2   489.932156  108.048667
# 3   478.130459   94.405037
# 4   281.415364  692.704145

# %%
dataset.plot.scatter(x="x", y="y")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df = pd.read_csv('dataset_209770_6.txt', sep=' ', header=None)
sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='0', ylabel='1'>

# %% [markdown]
# ### Скачайте данные, представляющие геномные расстояния между видами, и постройте тепловую карту, чтобы различия было видно наглядно. В ответ впишите, какая картинка соответствует скачанным данным.

# %% [markdown]
# Чтобы график отображался как на картинках, добавьте
#
# g = # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
# g.xaxis.set_ticks_position('top')
# g.xaxis.set_tick_params(rotation=90)

# %%
dataset = pd.read_csv('genome_matrix.csv', index_col=0)

# %%
dataset.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
ax = sns.heatmap(data=dataset, annot=True, cmap="viridis", linewidths=.3);

ax.xaxis.set_ticks_position('top')

ax.xaxis.set_tick_params(rotation=0)

# %% [markdown]
# ### Пришло время узнать, кто самый главный рак какая роль в dota самая распространённая.

# %%
 Скачайте датасэт с данными о героях из игры dota 2 и посмотрите на распределение их возможных ролей 
в игре (колонка roles). Постройте гистограмму, отражающую скольким
героям сколько ролей приписывается (по мнению Valve, конечно)
и напишите какое число ролей у большинства героев.
Это задание можно выполнить многими путями, и рисовать гистограмму вообще говоря для этого не нужно.
Данные взяты отсюда, на этом же сайте можно найти больше разнообразных данных по dota 2

# %%
dfr = pd.read_csv('dota_hero_stats.csv', index_col=0)

# %%
dfr.head(1000)
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# 0            agi                       ['Carry', 'Escape', 'Nuker']
# 1            str    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2            int        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3            agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4            int        ['Support', 'Disabler', 'Nuker', 'Jungler']
# ..           ...                                                ...
# 112          agi       ['Carry', 'Escape', 'Disabler', 'Initiator']
# 113          int         ['Support', 'Nuker', 'Disabler', 'Escape']
# 114          agi  ['Carry', 'Nuker', 'Disabler', 'Durable', 'Esc...
# 115          int         ['Support', 'Nuker', 'Disabler', 'Escape']
# 116          str      ['Carry', 'Initiator', 'Disabler', 'Durable']
#
# [117 rows x 7 columns]

# %%
a = dfr.roles.map(eval).map(len)
a.hist()
# Out:
# <AxesSubplot:>

# %%
a.mode()
# Out:
# 0    4
# dtype: int64

# %% [markdown]
# ### Теперь перейдём к цветочкам. Магистрантка Адель решила изучить какие бывают ирисы. Помогите Адель узнать об ирисах больше - скачайте датасэт со значениями параметров ирисов, постройте их распределения и отметьте правильные утверждения, глядя на график.
#
# Распределение должно быть по всем образцам, без разделения на вид.
# Чтобы построить на 1-ом графике распределения для каждого из параметров, можно воспользоваться петлёй

# %%
flwr = pd.read_csv('iris.csv')

# %%
# Заменяем пробелы в названиях колонок на нижнее подчёркивадние
flwr.rename(columns=lambda x:
                            x.replace(" ", "_"),
                            inplace=True)

# %%
flwr.head()
# Out:
#    Unnamed:_0  sepal_length  sepal_width  petal_length  petal_width  species
# 0           0           5.1          3.5           1.4          0.2        0
# 1           1           4.9          3.0           1.4          0.2        0
# 2           2           4.7          3.2           1.3          0.2        0
# 3           3           4.6          3.1           1.5          0.2        0
# 4           4           5.0          3.6           1.4          0.2        0

# %%
sns.kdeplot(data=flwr)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# унимодальное - с одним горбом на линии тренда
#
# бимодальное - с двумя
#
# размах - дельта от минимального до максимального значения

# %% [markdown]
# ###  Рассмотрим длину лепестков (petal length) подробнее и воспользуемся для этого violin плотом. Нарисуйте распределение длины лепестков ирисов из предыдущего датасэта с помощью violin плота и выберите правильный (такой же) вариант среди предложенных
#
# https://seaborn.pydata.org/generated/seaborn.violinplot.html

# %%
sns.violinplot(x=flwr["petal_length"])
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %% [markdown]
# ### Продолжаем изучение ирисов! Ещё один важный тип графиков - pairplot, отражающий зависимость пар переменных друг от друга, а также распределение каждой из переменных. Постройте его и посмотрите на scatter плоты для каждой из пар фичей. Какая из пар навскидку имеет наибольшую корреляцию?
#
# Также обратите внимание, что можно разделить на группы с помощью параметра hue.
#
# Ссылки для изучения: https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
flwr.head()
# Out:
#    Unnamed:_0  sepal_length  sepal_width  petal_length  petal_width  species
# 0           0           5.1          3.5           1.4          0.2        0
# 1           1           4.9          3.0           1.4          0.2        0
# 2           2           4.7          3.2           1.3          0.2        0
# 3           3           4.6          3.1           1.5          0.2        0
# 4           4           5.0          3.6           1.4          0.2        0

# %%
sns.pairplot(flwr)

# %%
sns.pairplot(flwr, hue='species')

# %%
коррелируется, значит лежат на одной прямой. и лучше это делать без всяких хуев

# %%
features = flwr.columns
f,ax = plt.subplots(1,1)
sns.heatmap(flwr[features].corr(), annot=True, square=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>
