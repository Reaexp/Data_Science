# %%
pip install pandas
# Out:
# ...
#
# ...
#      ---------------------------------------- 10.9/10.9 MB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 499.4/499.4 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.9/14.9 MB 2.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

# %%
student_performance = pd.read_csv('StudentsPerformance.csv')

# %%
student_performance.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# групировка по переменной
student_performance.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
# describe() - описательные статистики
student_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# dtypes - типы данных в датафрейме
student_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# сколько строк и колонок
student_performance.shape
# Out:
# (1000, 8)

# %%
student_performance.size
# Out:
# 8000

# %%
student_performance.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_performance.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
student_performance.iloc[0:5, 0:5]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none
# 3                    none
# 4                    none

# %%
student_performance.iloc[[0, 3, 10], [1, 5, 7]]
# Out:
#    race/ethnicity  math score  writing score
# 0         group B          72             74
# 3         group A          47             44
# 10        group C          58             52

# %%
student_performance_with_name = student_performance.iloc[[0, 3, 4, 7, 8]]

# %%
student_performance_with_name
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
student_performance_with_name.index = ["Cersel", "Tywin", "Gregor", "Joffrey", "Ilin Payne"]

# %%
student_performance_with_name
# Out:
#             gender race/ethnicity parental_level_of_education         lunch  \
# Cersel      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilin Payne    male        group D                 high school  free/reduced
#
#            test_preparation_course  math_score  reading_score  writing_score
# Cersel                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilin Payne               completed          64             64             67

# %%
student_performance_with_name.loc[['Cersel', 'Joffrey']]
# Out:
#          gender race/ethnicity parental level of education         lunch  \
# Cersel   female        group B           bachelor's degree      standard
# Joffrey    male        group B                some college  free/reduced
#
#         test preparation course  math score  reading score  writing score
# Cersel                     none          72             72             74
# Joffrey                    none          40             43             39

# %%
student_performance_with_name.iloc[[0, 3]]
# Out:
#          gender race/ethnicity parental level of education         lunch  \
# Cersel   female        group B           bachelor's degree      standard
# Joffrey    male        group B                some college  free/reduced
#
#         test preparation course  math score  reading score  writing score
# Cersel                     none          72             72             74
# Joffrey                    none          40             43             39

# %%
student_performance_with_name.iloc[[0, 3], [2, 3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 student_performance_with_name.iloc[[0, 3], [2, 3]]
#
# NameError: name 'student_performance_with_name' is not defined

# %%
type(student_performance_with_name.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3], index=["Cersel", "Tywin", "Gregor"])
# Out:
# Cersel    1
# Tywin     2
# Gregor    3
# dtype: int64

# %%
my_series_1 = pd.Series([1,2,3], index=["Cersel", "Tywin", "Gregor"])
my_series_2 = pd.Series([4,5,6], index=["Cersel", "Tywin", "Gregor"])

# %%
pd.DataFrame({'col_name_1':my_series_1, 'col_name_2':my_series_2})
# Out:
#         col_name_1  col_name_2
# Cersel           1           4
# Tywin            2           5
# Gregor           3           6

# %%
student_performance_with_name[['gender']]
# Out:
#             gender
# Cersel      female
# Tywin         male
# Gregor        male
# Joffrey       male
# Ilin Payne    male

# %%
student_performance_with_name['gender']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 student_performance_with_name['gender']
#
# NameError: name 'student_performance_with_name' is not defined

# %%
student_performance.iloc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78

# %% [markdown]
# ## 1.5 Фильтрация данных

# %%
student_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_performance.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
student_performance.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
student_performance.loc[student_performance.gender == 'female', ['gender', 'reading score']]
# Out:
#      gender  reading score
# 0    female             72
# 1    female             90
# 2    female             95
# 5    female             83
# 6    female             95
# ..      ...            ...
# 993  female             72
# 995  female             99
# 997  female             71
# 998  female             78
# 999  female             86
#
# [518 rows x 2 columns]

# %%
student_performance.writing score
# Out:
#   File "<ipython-input-22-9a4368d76822>", line 1
#     student_performance.writing score
#                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# не получается обратиться к reading score из за пробела

# %%
student_performance['writing score']
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %%
student_performance['writing score'].mean()
# Out:
# 68.054

# %%
mean_writing_score = student_performance['writing score'].mean()

# %%
student_performance.loc[student_performance['writing score'] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Аналитик Ярослав захотел отфильтровать данные по комбинации условий и отобрать только те наблюдения, у которых значение по переменной writing score >  100, а значение переменной gender == female. Для этого Ярослав написал следующий запрос:

# %%
student_performance[student_performance['writing score'] > 100 and student_performance.gender == 'female']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 student_performance[student_performance['writing score'] > 100 and student_performance.gender == 'female']
#
# File C:\Python 3911\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
student_performance[(student_performance['writing score']) > 100 & (student_performance.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# При работе с pandas series для логического И нужно использовать & вместо уже знакомого and
#
# Нужно указать приоритет операций, взяв условия в скобки [(condition) и (condition)]

# %%
(student_performance['writing score'] > mean_writing_score) & (student_performance.gender == 'female')
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
querty = (student_performance['writing score'] > mean_writing_score) & (student_performance.gender == 'female')

# %%
student_performance.loc[querty].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
student_performance.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
student_performance.gender == "female"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: gender, Length: 1000, dtype: bool

# %%
student_performance.loc[student_performance.gender == "female"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3    female        group A          associate's degree  free/reduced
# 4    female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996  female        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_performance.loc[student_performance.lunch == "standard"]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4    female        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987  female        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994  female        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
student_performance['writing score'].mean() # Cpeднее значение
# Out:
# 68.054

# %%
mean_writing_score = student_performance['writing score'].mean()

# %%
print(mean_writing_score)
# Out:
# 68.054

# %%
#вывод в таблицу значений выше среднего
student_performance.loc[student_performance['writing score'] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4    female        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#вывод в таблицу значений меньше 30
student_performance.loc[student_performance['writing score'] < 30]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 76     male        group E            some high school      standard
# 211    male        group C                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 896    male        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 17                     none          18             32             28
# 59                     none           0             17             10
# ...

# %%
student_performance.loc[student_performance.gender == "female", ['gender', 'writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %%
# Заменяем пробелы в названиях колонок на нижнее подчёркивадние
student_performance.rename(columns=lambda x:
                           x.replace(" ", "_"),
                           inplace=True)

# %%
student_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_performance.math_score
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math_score, Length: 1000, dtype: int64

# %%
student_performance.query('math_score > 74')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 13     male        group A                some college      standard
# 16     male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
student_performance.query('gender == "female" & math_score > 74')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 38   female        group D          associate's degree  free/reduced
# 56   female        group E          associate's degree      standard
# 86   female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 970  female        group D           bachelor's degree      standard
# 979  female        group C          associate's degree      standard
# 983  female        group A                some college      standard
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
student_performance.query('gender == "female" | math_score > 74')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
math_score_query = 90
student_performance.query("math_score > @math_score_query")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 171    male        group E            some high school      standard
# 179  female        group D            some high school      standard
# 233    male        group E            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# ...

# %%
student_performance[["math_score", "reading_score"]].head()
# Out:
#    math_score  reading_score
# 0          72             72
# 1          69             90
# 2          90             95
# 3          47             57
# 4          76             78

# %%
# Отбираем колонки вручную))) код ниже
list(student_performance)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course',
#  'math_score',
#  'reading_score',
#  'writing_score']

# %%
score_columns = [i for i in list(student_performance) if 'score' in i]
print(score_columns)
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
score_columns = [i for i in list(student_performance) if 'score' in i]

# %%
student_performance[score_columns].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
# Отбираем колонки с помощью Pandas filter
student_performance.filter(like='score').head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
student_performance_with_name.filter(like='e')
# Out:
#    gender race/ethnicity parental_level_of_education test_preparation_course  \
# 0  female        group B           bachelor's degree                    none
# 3    male        group A          associate's degree                    none
# 4    male        group C                some college                    none
# 7    male        group B                some college                    none
# 8    male        group D                 high school               completed
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 3          47             57             44
# 4          76             78             75
# 7          40             43             39
# 8          64             64             67

# %%
student_performance_with_name.filter(like='e', axis=0) # проверяет есть ли "e" в названиях строк
# axis=0 Обращение к строкам
# Out:
#             gender race/ethnicity parental_level_of_education         lunch  \
# Cersel      female        group B           bachelor's degree      standard
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilin Payne    male        group D                 high school  free/reduced
#
#            test_preparation_course  math_score  reading_score  writing_score
# Cersel                        none          72             72             74
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilin Payne               completed          64             64             67

# %%
student_performance_with_name.filter(like='core', axis=1) # проверяет есть ли "core" в названиях колонок
# axis# axis=1 Обращение к колонкам
# Out:
#             math_score  reading_score  writing_score
# Cersel              72             72             74
# Tywin               47             57             44
# Gregor              76             78             75
# Joffrey             40             43             39
# Ilin Payne          64             64             67
